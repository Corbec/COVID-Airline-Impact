# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
financial = pd.read_csv('../data/690079960_T_F41SCHEDULE_B11.csv')

# %%
financial
# Out:
#       CASH  PROP_EQUIP_OWNED  PROP_EQUIP    ASSETS  LONG_TERM_DEBT  \
# 0    87.50           6255.80     1836.65   2141.26             NaN
# 1  1180.92            290.47       32.46   1741.58            0.00
# 2  1420.70            364.37       78.15   4559.43          292.75
# 3  2113.30            211.62      119.12   3842.67         2879.48
# 4  4669.72            402.82      316.47   7842.39            0.00
# 5  7936.32          13150.69     8342.21  17457.02             NaN
# 6  7983.43          11877.59     2773.31  22638.01         1730.10
#
#    AIRLINE_ID UNIQUE_CARRIER  \
# 0       20201            AMQ
# 1       21754            2PQ
# 2       21402             PM
# 3       21854            34Q
# 4       21875            37Q
# 5       19998             SI
# 6       21518            1EQ
#
#                                  UNIQUE_CARRIER_NAME CARRIER  \
# 0                                Ameristar Air Cargo     AMQ
# ...

# %%
financial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CASH                   7 non-null      float64
#  1   PROP_EQUIP_OWNED       7 non-null      float64
#  2   PROP_EQUIP             7 non-null      float64
#  3   ASSETS                 7 non-null      float64
#  4   LONG_TERM_DEBT         5 non-null      float64
#  5   AIRLINE_ID             7 non-null      int64
#  6   UNIQUE_CARRIER         7 non-null      object
#  7   UNIQUE_CARRIER_NAME    7 non-null      object
#  8   CARRIER                7 non-null      object
#  9   CARRIER_NAME           7 non-null      object
#  10  UNIQUE_CARRIER_ENTITY  7 non-null      int64
#  11  REGION                 7 non-null      object
#  12  YEAR                   7 non-null      int64
#  13  QUARTER                7 non-null      int64
# ...

# %%
airline = pd.read_csv('../data/690079960_T_T100D_MARKET_ALL_CARRIER.csv')

# %%
airline
# Out:
#        PASSENGERS   FREIGHT     MAIL  DISTANCE UNIQUE_CARRIER  AIRLINE_ID  \
# 0             0.0       0.0      0.0     104.0             YX       20452
# 1             0.0       0.0      0.0      77.0             YX       20452
# 2             0.0       0.0      0.0      30.0             YX       20452
# 3             0.0       0.0      0.0     228.0             YX       20452
# 4             0.0       0.0      0.0     466.0             YX       20452
# ...           ...       ...      ...       ...            ...         ...
# 86373     72962.0  557005.0      0.0     100.0             HA       19690
# 86374     84608.0   53043.0  48706.0     404.0             DL       19790
# 86375     85349.0  102062.0  11010.0     404.0             DL       19790
# 86376     86715.0   78459.0  69237.0     404.0             DL       19790
# 86377     91173.0   95116.0  24689.0     404.0             DL       19790
#
#           UNIQUE_CARRIER_NAME UNIQUE_CARRIER_ENTITY REGION CARRIER  ...  \
# ...

# %%
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86378 entries, 0 to 86377
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PASSENGERS             86378 non-null  float64
#  1   FREIGHT                86378 non-null  float64
#  2   MAIL                   86378 non-null  float64
#  3   DISTANCE               86378 non-null  float64
#  4   UNIQUE_CARRIER         86378 non-null  object
#  5   AIRLINE_ID             86378 non-null  int64
#  6   UNIQUE_CARRIER_NAME    86378 non-null  object
#  7   UNIQUE_CARRIER_ENTITY  86378 non-null  object
#  8   REGION                 86378 non-null  object
#  9   CARRIER                86378 non-null  object
#  10  CARRIER_NAME           86378 non-null  object
#  11  CARRIER_GROUP          86378 non-null  int64
#  12  CARRIER_GROUP_NEW      86378 non-null  int64
#  13  ORIGIN_AIRPORT_ID      86378 non-null  int64
# ...

# %%
traffic_2020 = pd.read_csv('../data/2020/690079960_T_T100D_MARKET_US_CARRIER_ONLY.csv')

# %%
traffic_2020
# Out:
#         PASSENGERS   FREIGHT     MAIL  DISTANCE UNIQUE_CARRIER  AIRLINE_ID  \
# 0              0.0    3441.0  23433.0     101.0             L2       20169
# 1              0.0    7129.0      0.0     442.0             L2       20169
# 2              0.0       0.0      0.0     405.0             L2       20169
# 3              0.0   48702.0   2948.0     399.0             L2       20169
# 4              0.0    8606.0      0.0     204.0             L2       20169
# ...            ...       ...      ...       ...            ...         ...
# 128537     72962.0  557005.0      0.0     100.0             HA       19690
# 128538     84608.0   53043.0  48706.0     404.0             DL       19790
# 128539     85349.0  102062.0  11010.0     404.0             DL       19790
# 128540     86715.0   78459.0  69237.0     404.0             DL       19790
# 128541     91173.0   95116.0  24689.0     404.0             DL       19790
#
# ...

# %%
traffic_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128542 entries, 0 to 128541
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   PASSENGERS             128542 non-null  float64
#  1   FREIGHT                128542 non-null  float64
#  2   MAIL                   128542 non-null  float64
#  3   DISTANCE               128542 non-null  float64
#  4   UNIQUE_CARRIER         128542 non-null  object
#  5   AIRLINE_ID             128542 non-null  int64
#  6   UNIQUE_CARRIER_NAME    128542 non-null  object
#  7   UNIQUE_CARRIER_ENTITY  128542 non-null  object
#  8   REGION                 128542 non-null  object
#  9   CARRIER                128542 non-null  object
#  10  CARRIER_NAME           128542 non-null  object
#  11  CARRIER_GROUP          128542 non-null  int64
#  12  CARRIER_GROUP_NEW      128542 non-null  int64
#  13  ORIGIN_AIRPORT_ID      128542 non-null  int64
# ...

# %%
traffic_2019 = pd.read_csv('../data/2019/690079960_T_T100D_MARKET_US_CARRIER_ONLY.csv')

# %%
traffic_2019
# Out:
#         PASSENGERS   FREIGHT     MAIL  DISTANCE UNIQUE_CARRIER  AIRLINE_ID  \
# 0              0.0   34255.0      0.0     160.0             EM       20263
# 1              0.0   78135.0      0.0     149.0             EM       20263
# 2              0.0  139580.0      0.0     321.0             EM       20263
# 3              0.0  212614.0      0.0     264.0             EM       20263
# 4              0.0  133799.0      0.0     294.0             EM       20263
# ...            ...       ...      ...       ...            ...         ...
# 251545     96984.0  505308.0  15979.0    1448.0             AS       19930
# 251546     97011.0  473666.0  55963.0    1448.0             AS       19930
# 251547     97098.0  592775.0  18834.0    1448.0             AS       19930
# 251548     97329.0  210292.0   5431.0     404.0             DL       19790
# 251549     97644.0  390399.0  44506.0    1448.0             AS       19930
#
# ...

# %%
traffic_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251550 entries, 0 to 251549
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   PASSENGERS             251550 non-null  float64
#  1   FREIGHT                251550 non-null  float64
#  2   MAIL                   251550 non-null  float64
#  3   DISTANCE               251550 non-null  float64
#  4   UNIQUE_CARRIER         251550 non-null  object
#  5   AIRLINE_ID             251550 non-null  int64
#  6   UNIQUE_CARRIER_NAME    251550 non-null  object
#  7   UNIQUE_CARRIER_ENTITY  251550 non-null  object
#  8   REGION                 251550 non-null  object
#  9   CARRIER                251550 non-null  object
#  10  CARRIER_NAME           251550 non-null  object
#  11  CARRIER_GROUP          251550 non-null  int64
#  12  CARRIER_GROUP_NEW      251550 non-null  int64
#  13  ORIGIN_AIRPORT_ID      251550 non-null  int64
# ...

# %%
employees_2020 = pd.read_csv('../data/690079960_T_F41SCHEDULE_P1A_EMP- 2020.csv')

# %%
employees_2020
# Out:
#      YEAR  MONTH  AIRLINE_ID UNIQUE_CARRIER  \
# 0    2020      4       21161            09Q
# 1    2020      4       21352            0WQ
# 2    2020      4       21492            1BQ
# 3    2020      4       21518            1EQ
# 4    2020      4       21577            1TQ
# ..    ...    ...         ...            ...
# 512  2020      9       19393             WN
# 513  2020      9       20377             X9
# 514  2020      9       20207             XP
# 515  2020      9       20378             YV
# 516  2020      9       20452             YX
#
#                                    UNIQUE_CARRIER_NAME CARRIER  \
# 0    Swift Air, LLC d/b/a Eastern Air Lines d/b/a E...     09Q
# 1                                    Avjet Corporation     0WQ
# 2          Eastern Airlines f/k/a Dynamic Airways, LLC     1BQ
# 3                                      KaiserAir, Inc.     1EQ
# 4                        Rhoades Aviation dba Transair     1TQ
# ...

# %%
employees_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   YEAR                 517 non-null    int64
#  1   MONTH                517 non-null    int64
#  2   AIRLINE_ID           517 non-null    int64
#  3   UNIQUE_CARRIER       517 non-null    object
#  4   UNIQUE_CARRIER_NAME  517 non-null    object
#  5   CARRIER              517 non-null    object
#  6   CARRIER_NAME         517 non-null    object
#  7   CARRIER_GROUP        517 non-null    int64
#  8   CARRIER_GROUP_NEW    517 non-null    int64
#  9   EMPFULL              517 non-null    int64
#  10  EMPPART              517 non-null    int64
#  11  EMPTOTAL             517 non-null    int64
#  12  EMPFTE               517 non-null    int64
#  13  Unnamed: 13          0 non-null      float64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 56.7+ KB

# %%
trans_states_2020 = employees_2020[employees_2020['CARRIER'] == 'AX']

# %%
trans_states_2020
# Out:
# Empty DataFrame
# Columns: [YEAR, MONTH, AIRLINE_ID, UNIQUE_CARRIER, UNIQUE_CARRIER_NAME, CARRIER, CARRIER_NAME, CARRIER_GROUP, CARRIER_GROUP_NEW, EMPFULL, EMPPART, EMPTOTAL, EMPFTE, Unnamed: 13]
# Index: []

# %%
employees_2019 = pd.read_csv('../data/986050249_T_F41SCHEDULE_P1A_EMP - 2019.csv')

# %%
employees_2019
# Out:
#      YEAR  MONTH  AIRLINE_ID UNIQUE_CARRIER  \
# 0    2019      1       21161            09Q
# 1    2019      1       21352            0WQ
# 2    2019      1       21492            1BQ
# 3    2019      1       21518            1EQ
# 4    2019      1       21652            27Q
# ..    ...    ...         ...            ...
# 709  2019     12       20377             X9
# 710  2019     12       20207             XP
# 711  2019     12       20378             YV
# 712  2019     12       20452             YX
# 713  2019     12       20046             ZW
#
#                                    UNIQUE_CARRIER_NAME CARRIER  \
# 0    Swift Air, LLC d/b/a Eastern Air Lines d/b/a E...     09Q
# 1                                    Avjet Corporation     0WQ
# 2          Eastern Airlines f/k/a Dynamic Airways, LLC     1BQ
# 3                                      KaiserAir, Inc.     1EQ
# 4                   Jet Aviation Flight Services, Inc.     27Q
# ...

# %%
trans_states_2019 = employees_2019[employees_2019['CARRIER'] == 'AX']

# %%
trans_states_2019
# Out:
# Empty DataFrame
# Columns: [YEAR, MONTH, AIRLINE_ID, UNIQUE_CARRIER, UNIQUE_CARRIER_NAME, CARRIER, CARRIER_NAME, CARRIER_GROUP, CARRIER_GROUP_NEW, EMPFULL, EMPPART, EMPTOTAL, EMPFTE, Unnamed: 13]
# Index: []
